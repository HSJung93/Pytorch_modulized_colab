# %%
pip install --upgrade efficientnet-pytorch
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.0-cp36-none-any.whl size=16031 sha256=a9478dff13761932903c64707ef5fae19e631bdb84f6b1be66677800f552a745
#   Stored in directory: /root/.cache/pip/wheels/e9/c6/e1/7a808b26406239712cfce4b5ceeb67d9513ae32aa4b31445c6
# Successfully built efficientnet-pytorch
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/colab/pytorch_tutorial/classification
# Out:
# /content/gdrive/My Drive/colab/pytorch_tutorial/classification

# %%
# all you have to do is to erase ! when using local machine instead of colab
# !python3 main.py --dataset CIFAR10 --batch_size 100 --epochs 5
# Out:
# Namespace(batch_size=100, classes=10, dataset='CIFAR10', efficientnet='b0', epochs=5, interval=1, learning_rate=0.001, model_name=None, pretrained_weights=None)
# CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified
# Completed reading the dataset
# Loaded pretrained weights for efficientnet-b0
# Completed loading the model
# cuda:0 is available.
# Start!
# [1] loss: 1.043
# Save model parameters = [1] loss: 1.043
# [2] loss: 0.633
# Save model parameters = [2] loss: 0.633
# [3] loss: 0.508
# Save model parameters = [3] loss: 0.508
# [4] loss: 0.418
# Save model parameters = [4] loss: 0.418
# [5] loss: 0.360
# Save model parameters = [5] loss: 0.360
# Test Accuracy: 90 %
# Completed training the model

# %%
# --pretrained_weights /contents/gdrive/My Drive/classification/savemodel/trained_model1.pth
